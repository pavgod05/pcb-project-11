# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/oroject/dataset-pcb.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/oroject/dataset-pcb.zip
# replace /content/dataset-pcb/images/train/01_missing_hole_01.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/dataset-pcb/images/train/01_missing_hole_02.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_04.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_07.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_08.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_09.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_10.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_11.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_13.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_15.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17851, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 17851 (delta 33), reused 9 (delta 9), pack-reused 17798 (from 2)
# Receiving objects: 100% (17851/17851), 17.00 MiB | 29.11 MiB/s, done.
# Resolving deltas: 100% (12169/12169), done.

# %%
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content

# %%
model = YOLO("yolo11n.pt")

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
model.train(
    data="dataset.yaml",
    epochs=50,
    imgsz=416,
    batch=16,
    name="pcb_1st"
)
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r /content/drive/MyDrive/oroject/dataset-pcb.zip /content/yolov5/runs
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/pcb_1st/ (stored 0%)
#   adding: content/yolov5/runs/train/pcb_1st/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/pcb_1st/train_batch1.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/pcb_1st/train_batch2.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/pcb_1st/P_curve.png (deflated 6%)
#   adding: content/yolov5/runs/train/pcb_1st/labels.jpg (deflated 27%)
#   adding: content/yolov5/runs/train/pcb_1st/results.png (deflated 7%)
#   adding: content/yolov5/runs/train/pcb_1st/val_batch2_pred.jpg (deflated 24%)
#   adding: content/yolov5/runs/train/pcb_1st/val_batch2_labels.jpg (deflated 24%)
#   adding: content/yolov5/runs/train/pcb_1st/val_batch1_labels.jpg (deflated 14%)
#   adding: content/yolov5/runs/train/pcb_1st/F1_curve.png (deflated 6%)
#   adding: content/yolov5/runs/train/pcb_1st/R_curve.png (deflated 7%)
# ...

# %%
import os

dataset_yaml_content = """
# YOLOv5 PCB Defect Dataset Configuration

# Root directory for dataset
path: /content/dataset-pcb

# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2]
train: images/train  # train images (relative to 'path')
val: images/val      # val images (relative to 'path')
# test: images/test  # test images (optional)

# Classes
nc: 6  # number of classes
names: ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'solder_ball']  # class names
"""

# Define the path where dataset.yaml should be created
dataset_yaml_path = '/content/dataset-pcb/dataset.yaml'

# Write the content to the file
with open(dataset_yaml_path, 'w') as f:
    f.write(dataset_yaml_content)

print(f"Created dataset.yaml at: {dataset_yaml_path}")
# !cat {dataset_yaml_path}
# Out:
# Created dataset.yaml at: /content/dataset-pcb/dataset.yaml
#
# # YOLOv5 PCB Defect Dataset Configuration
#
# # Root directory for dataset
# path: /content/dataset-pcb
#
# # Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2]
# train: images/train  # train images (relative to 'path')
# val: images/val      # val images (relative to 'path')
# # test: images/test  # test images (optional)
#
# # Classes
# nc: 6  # number of classes
# names: ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'solder_ball']  # class names

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Train the model using the dataset.yaml and specify a project name
model.train(data='/content/dataset-pcb/dataset.yaml', epochs=50, imgsz=416, batch=16, name='pcb_yolov8_1st')
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import os

dataset_yaml_content = """
# YOLOv5 PCB Defect Dataset Configuration

# Root directory for dataset
path: /content/dataset-pcb

# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2]
train: images/train  # train images (relative to 'path')
val: images/val      # val images (relative to 'path')
# test: images/test  # test images (optional)

# Classes
nc: 6  # number of classes
names: ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'solder_ball']  # class names
"""

# Define the path where dataset.yaml should be created
dataset_yaml_path = '/content/yolov5/dataset.yaml' # Changed path to /content/yolov5

# Write the content to the file
with open(dataset_yaml_path, 'w') as f:
    f.write(dataset_yaml_content)

print(f"Created dataset.yaml at: {dataset_yaml_path}")
# !cat {dataset_yaml_path}
# Out:
# Created dataset.yaml at: /content/yolov5/dataset.yaml
#
# # YOLOv5 PCB Defect Dataset Configuration
#
# # Root directory for dataset
# path: /content/dataset-pcb
#
# # Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2]
# train: images/train  # train images (relative to 'path')
# val: images/val      # val images (relative to 'path')
# # test: images/test  # test images (optional)
#
# # Classes
# nc: 6  # number of classes
# names: ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'solder_ball']  # class names

# %%
# %cd /content
print('Changed directory to /content')
# Out:
# /content
# Changed directory to /content

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Train the model using the dataset.yaml and specify a project name
model.train(data='/content/yolov5/dataset.yaml', epochs=50, imgsz=416, batch=16, name='pcb_yolov8_1st')
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/oroject/
